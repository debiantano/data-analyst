# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Declaramos los eventos pasados

# %%
entrada = np.array([1, 6, 30, 7, 70, 45, 503, 201, 1005, 99], dtype=float)
resultados = np.array([0.0254, 0.1524, 0.762, 0.1778, 1.778, 1.0922, 12.776, 5.1054, 25.527, 2.514], dtype=float)

# %% [markdown]
# Topografia de la red

# %%
capa1 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %% [markdown]
# Creamos el tipo de red

# %%
modelo = tf.keras.Sequential([capa1])

# %% [markdown]
# Asignamos optimizador y metrica de perdidas

# %%
modelo.compile(
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss = "mean_squared_error"
)

# %% [markdown]
# ## Entrenamos el modelo

# %%
entrenamiento = modelo.fit(entrada, resultados, epochs=500, verbose=True)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1114
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1106
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1099
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1091
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1083
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1076
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1068
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1061
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1053
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1046
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1039
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1032
# ...

# %% [markdown]
# Guardar la red

# %%
modelo.save("RedNeuronal.h5")
modelo.save_weights("pesos.h5")

# %% [markdown]
# Observar el comportamiento de la red

# %%
plt.xlabel("Ciclos de entrenamiento")
plt.ylabel("Errores")
plt.plot(entrenamiento.history["loss"])

# %%
print("Terminando de entrenar")
# Out:
# Terminando de entrenar

# %% [markdown]
# ## Prediccion

# %%
i = input("Valor en pulgadas: ")
i = float(i)

prediccion = modelo.predict([i])
print("Valor en metros es: ", str(prediccion))
# Out:
# Valor en pulgadas: 822
# 1/1 [==============================] - 0s 45ms/step
# Valor en metros es:  [[20.969294]]
